# %%
TIMEZONEDB_KEY = 'Z5ZDUWG4ZBMU'
TIMEZONEDB_API_ROOT = 'http://api.timezonedb.com/v2.1/'
TZDB_API_GET_LIST = TIMEZONEDB_API_ROOT+'list-time-zone'
TZDB_API_GET_TIMEZONE = TIMEZONEDB_API_ROOT+'get-time-zone'
DB_CONNECTION_STRING = "postgres://zjhpqlmr:oSLJD_OEBSrn-bUS8_KSTaOANjoE0WqU@fanny.db.elephantsql.com/zjhpqlmr"

# %%
import requests
import psycopg2
import time

# %%
dbDict={}

conn = psycopg2.connect(DB_CONNECTION_STRING)
with conn:
  with conn.cursor() as curs:
    try:
      # Establish params and pull zone list
      params = {
        "key":TIMEZONEDB_KEY,
        "format":"json",
        "by":"zone",
      }
      timezoneList = requests.get(TZDB_API_GET_LIST,params)
      
      # Clear existing data
      curs.execute('TRUNCATE TABLE tzdb_timezones')
      conn.commit()
      # Copy list to db
      for zone in timezoneList.json()['zones']:
        curs.execute(f"INSERT INTO tzdb_timezones VALUES ('{zone['countryCode']}','{zone['countryName']}','{zone['zoneName']}',{zone['gmtOffset']})")
        conn.commit()

      # Build db dictionary
      curs.execute('SELECT * FROM tzdb_zone_details')
      for record in curs:
        dbDict.update({record[2]:{
          "countryCode":record[0],
          "countryName":record[1],
          "zoneName":record[2],
          "gmtOffset":record[3],
          "dst":record[4],
          "zoneStart":record[5],
          "zoneEnd":record[6]
        }})

      # Check dictionary against pulled data
      # curs.execute('SELECT * FROM tzdb_timezones')
      for zone in timezoneList.json()['zones']:
        print(f"Checking {zone['zoneName']}, {zone['countryName']}")
        # If not there, add to db
        if zone['zoneName'] not in dbDict:
          time.sleep(2)
          print("Doesn't exist, pulling data and adding to db...")
          params.update({"zone":zone['zoneName']})
          timezoneDetails = requests.get(TZDB_API_GET_TIMEZONE,params)
          timezoneDetails = timezoneDetails.json()

          curs.execute(f"INSERT INTO tzdb_zone_details (countrycode, countryname, zonename, gmtoffset, dst, zonestart, zoneend) VALUES ('{timezoneDetails['countryCode']}','{timezoneDetails['countryName']}','{timezoneDetails['zoneName']}',{timezoneDetails['gmtOffset']},{timezoneDetails['dst']},{timezoneDetails['zoneStart']},{'null' if timezoneDetails['zoneEnd']==None else timezoneDetails['zoneEnd']})")
          conn.commit()
          print('Done')

    except Exception as err:
      print('Error', err)
      message = f'{err=}'
      message = message.replace("'","")
      curs.execute(f"insert into tzdb_error_log (error_message) values ('{message}')")
      conn.commit()
# Out:
# Checking Africa/Abidjan, Ivory Coast
# Checking Africa/Accra, Ghana
# Checking Africa/Addis_Ababa, Ethiopia
# Checking Africa/Algiers, Algeria
# Checking Africa/Asmara, Eritrea
# Checking Africa/Bamako, Mali
# Checking Africa/Bangui, Central African Republic
# Checking Africa/Banjul, Gambia
# Checking Africa/Bissau, Guinea-Bissau
# Checking Africa/Blantyre, Malawi
# Checking Africa/Brazzaville, Republic of the Congo
# Checking Africa/Bujumbura, Burundi
# Checking Africa/Cairo, Egypt
# Checking Africa/Casablanca, Morocco
# Checking Africa/Ceuta, Spain
# Checking Africa/Conakry, Guinea
# Checking Africa/Dakar, Senegal
# Checking Africa/Dar_es_Salaam, Tanzania
# Checking Africa/Djibouti, Djibouti
# Checking Africa/Douala, Cameroon
# Checking Africa/El_Aaiun, Morocco
# Checking Africa/Freetown, Sierra Leone
# Checking Africa/Gaborone, Botswana
# Checking Africa/Harare, Zimbabwe
# Checking Africa/Johannesburg, South Africa
# Checking Africa/Juba, South Sudan
# Checking Africa/Kampala, Uganda
# Checking Africa/Khartoum, Sudan
# Checking Africa/Kigali, Rwanda
# Checking Africa/Kinshasa, Democratic Republic of the Congo
# Checking Africa/Lagos, Nigeria
# Checking Africa/Libreville, Gabon
# Checking Africa/Lome, Togo
# Checking Africa/Luanda, Angola
# Checking Africa/Lubumbashi, Democratic Republic of the Congo
# Checking Africa/Lusaka, Zambia
# Checking Africa/Malabo, Equatorial Guinea
# Checking Africa/Maputo, Mozambique
# Checking Africa/Maseru, Lesotho
# Checking Africa/Mbabane, Eswatini
# Checking Africa/Mogadishu, Somalia
# Checking Africa/Monrovia, Liberia
# Checking Africa/Nairobi, Kenya
# Checking Africa/Ndjamena, Chad
# Checking Africa/Niamey, Niger
# Checking Africa/Nouakchott, Mauritania
# Checking Africa/Ouagadougou, Burkina Faso
# Checking Africa/Porto-Novo, Benin
# Checking Africa/Sao_Tome, Sao Tome and Principe
# Checking Africa/Tripoli, Libya
# Checking Africa/Tunis, Tunisia
# Checking Africa/Windhoek, Namibia
# Checking America/Adak, United States
# Checking America/Anchorage, United States
# Checking America/Anguilla, Anguilla
# Checking America/Antigua, Antigua and Barbuda
# Checking America/Araguaina, Brazil
# Checking America/Argentina/Buenos_Aires, Argentina
# Checking America/Argentina/Catamarca, Argentina
# Checking America/Argentina/Cordoba, Argentina
# Checking America/Argentina/Jujuy, Argentina
# Checking America/Argentina/La_Rioja, Argentina
# Checking America/Argentina/Mendoza, Argentina
# Checking America/Argentina/Rio_Gallegos, Argentina
# Checking America/Argentina/Salta, Argentina
# Checking America/Argentina/San_Juan, Argentina
# Checking America/Argentina/San_Luis, Argentina
# Checking America/Argentina/Tucuman, Argentina
# Checking America/Argentina/Ushuaia, Argentina
# Checking America/Aruba, Aruba
# Checking America/Asuncion, Paraguay
# Checking America/Atikokan, Canada
# Checking America/Bahia, Brazil
# Checking America/Bahia_Banderas, Mexico
# Checking America/Barbados, Barbados
# Checking America/Belem, Brazil
# Checking America/Belize, Belize
# Checking America/Blanc-Sablon, Canada
# Checking America/Boa_Vista, Brazil
# Checking America/Bogota, Colombia
# Checking America/Boise, United States
# Checking America/Cambridge_Bay, Canada
# Checking America/Campo_Grande, Brazil
# Checking America/Cancun, Mexico
# Checking America/Caracas, Venezuela
# Checking America/Cayenne, French Guiana
# Checking America/Cayman, Cayman Islands
# Checking America/Chicago, United States
# Checking America/Chihuahua, Mexico
# Checking America/Costa_Rica, Costa Rica
# Checking America/Creston, Canada
# Checking America/Cuiaba, Brazil
# Checking America/Curacao, Curacao
# Checking America/Danmarkshavn, Greenland
# Checking America/Dawson, Canada
# Checking America/Dawson_Creek, Canada
# Checking America/Denver, United States
# Checking America/Detroit, United States
# Checking America/Dominica, Dominica
# Checking America/Edmonton, Canada
# Checking America/Eirunepe, Brazil
# Checking America/El_Salvador, El Salvador
# Checking America/Fort_Nelson, Canada
# Checking America/Fortaleza, Brazil
# Checking America/Glace_Bay, Canada
# Checking America/Goose_Bay, Canada
# Checking America/Grand_Turk, Turks and Caicos Islands
# Checking America/Grenada, Grenada
# Checking America/Guadeloupe, Guadeloupe
# Checking America/Guatemala, Guatemala
# Checking America/Guayaquil, Ecuador
# Checking America/Guyana, Guyana
# Checking America/Halifax, Canada
# Checking America/Havana, Cuba
# Checking America/Hermosillo, Mexico
# Checking America/Indiana/Indianapolis, United States
# Checking America/Indiana/Knox, United States
# Checking America/Indiana/Marengo, United States
# Checking America/Indiana/Petersburg, United States
# Checking America/Indiana/Tell_City, United States
# Checking America/Indiana/Vevay, United States
# Checking America/Indiana/Vincennes, United States
# Checking America/Indiana/Winamac, United States
# Checking America/Inuvik, Canada
# Checking America/Iqaluit, Canada
# Checking America/Jamaica, Jamaica
# Checking America/Juneau, United States
# Checking America/Kentucky/Louisville, United States
# Checking America/Kentucky/Monticello, United States
# Checking America/Kralendijk, Bonaire, Saint Eustatius and Saba
# Checking America/La_Paz, Bolivia
# Checking America/Lima, Peru
# Checking America/Los_Angeles, United States
# Checking America/Lower_Princes, Sint Maarten
# Checking America/Maceio, Brazil
# Checking America/Managua, Nicaragua
# Checking America/Manaus, Brazil
# Checking America/Marigot, Saint Martin
# Checking America/Martinique, Martinique
# Checking America/Matamoros, Mexico
# Checking America/Mazatlan, Mexico
# Checking America/Menominee, United States
# Checking America/Merida, Mexico
# Checking America/Metlakatla, United States
# Checking America/Mexico_City, Mexico
# Checking America/Miquelon, Saint Pierre and Miquelon
# Checking America/Moncton, Canada
# Checking America/Monterrey, Mexico
# Checking America/Montevideo, Uruguay
# Checking America/Montserrat, Montserrat
# Checking America/Nassau, Bahamas
# Checking America/New_York, United States
# Checking America/Nome, United States
# Checking America/Noronha, Brazil
# Checking America/North_Dakota/Beulah, United States
# Checking America/North_Dakota/Center, United States
# Checking America/North_Dakota/New_Salem, United States
# Checking America/Nuuk, Greenland
# Checking America/Ojinaga, Mexico
# Checking America/Panama, Panama
# Checking America/Pangnirtung, Canada
# Checking America/Paramaribo, Suriname
# Checking America/Phoenix, United States
# Checking America/Port-au-Prince, Haiti
# Checking America/Port_of_Spain, Trinidad and Tobago
# Checking America/Porto_Velho, Brazil
# Checking America/Puerto_Rico, Puerto Rico
# Checking America/Punta_Arenas, Chile
# Checking America/Rankin_Inlet, Canada
# Checking America/Recife, Brazil
# Checking America/Regina, Canada
# Checking America/Resolute, Canada
# Checking America/Rio_Branco, Brazil
# Checking America/Santarem, Brazil
# Checking America/Santiago, Chile
# Checking America/Santo_Domingo, Dominican Republic
# Checking America/Sao_Paulo, Brazil
# Checking America/Scoresbysund, Greenland
# Checking America/Sitka, United States
# Checking America/St_Barthelemy, Saint Barthelemy
# Checking America/St_Johns, Canada
# Checking America/St_Kitts, Saint Kitts and Nevis
# Checking America/St_Lucia, Saint Lucia
# Checking America/St_Thomas, U.S. Virgin Islands
# Checking America/St_Vincent, Saint Vincent and the Grenadines
# Checking America/Swift_Current, Canada
# Checking America/Tegucigalpa, Honduras
# Checking America/Thule, Greenland
# Checking America/Tijuana, Mexico
# Checking America/Toronto, Canada
# Checking America/Tortola, British Virgin Islands
# Checking America/Vancouver, Canada
# Checking America/Whitehorse, Canada
# Checking America/Winnipeg, Canada
# Checking America/Yakutat, United States
# Checking America/Yellowknife, Canada
# Checking Antarctica/Casey, Antarctica
# Checking Antarctica/Davis, Antarctica
# Checking Antarctica/DumontDUrville, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/DumontDUrville', 'abbreviation': 'DDUT', 'gmtOffset': 36000, 'dst': '0', 'zoneStart': -2366790512, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675388780, 'formatted': '2023-02-03 01:46:20'}
# Done
# Checking Antarctica/Macquarie, Australia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AU', 'countryName': 'Australia', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Macquarie', 'abbreviation': 'AEDT', 'gmtOffset': 39600, 'dst': '1', 'zoneStart': 1664640000, 'zoneEnd': 1680364799, 'nextAbbreviation': 'AEST', 'timestamp': 1675392382, 'formatted': '2023-02-03 02:46:22'}
# Done
# Checking Antarctica/Mawson, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Mawson', 'abbreviation': 'MAWT', 'gmtOffset': 18000, 'dst': '0', 'zoneStart': 1255809600, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675370785, 'formatted': '2023-02-02 20:46:25'}
# Done
# Checking Antarctica/McMurdo, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/McMurdo', 'abbreviation': 'NZDT', 'gmtOffset': 46800, 'dst': '1', 'zoneStart': 1664028000, 'zoneEnd': 1680357599, 'nextAbbreviation': 'NZST', 'timestamp': 1675399587, 'formatted': '2023-02-03 04:46:27'}
# Done
# Checking Antarctica/Palmer, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Palmer', 'abbreviation': 'CLST', 'gmtOffset': -10800, 'dst': '1', 'zoneStart': 1471147200, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675341989, 'formatted': '2023-02-02 12:46:29'}
# Done
# Checking Antarctica/Rothera, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Rothera', 'abbreviation': 'ART', 'gmtOffset': -10800, 'dst': '0', 'zoneStart': 218246400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675341992, 'formatted': '2023-02-02 12:46:32'}
# Done
# Checking Antarctica/Syowa, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Syowa', 'abbreviation': 'SYOT', 'gmtOffset': 10800, 'dst': '0', 'zoneStart': -719636812, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675363594, 'formatted': '2023-02-02 18:46:34'}
# Done
# Checking Antarctica/Troll, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Troll', 'abbreviation': 'GMT', 'gmtOffset': 0, 'dst': '0', 'zoneStart': 1667091600, 'zoneEnd': 1679792399, 'nextAbbreviation': 'CEST', 'timestamp': 1675352796, 'formatted': '2023-02-02 15:46:36'}
# Done
# Checking Antarctica/Vostok, Antarctica
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AQ', 'countryName': 'Antarctica', 'regionName': '', 'cityName': '', 'zoneName': 'Antarctica/Vostok', 'abbreviation': 'VOST', 'gmtOffset': 21600, 'dst': '0', 'zoneStart': -1325483420, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675374399, 'formatted': '2023-02-02 21:46:39'}
# Done
# Checking Arctic/Longyearbyen, Svalbard and Jan Mayen
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'SJ', 'countryName': 'Svalbard and Jan Mayen', 'regionName': '', 'cityName': '', 'zoneName': 'Arctic/Longyearbyen', 'abbreviation': 'CET', 'gmtOffset': 3600, 'dst': '0', 'zoneStart': 1667091600, 'zoneEnd': 1679792399, 'nextAbbreviation': 'CEST', 'timestamp': 1675356401, 'formatted': '2023-02-02 16:46:41'}
# Done
# Checking Asia/Aden, Yemen
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'YE', 'countryName': 'Yemen', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Aden', 'abbreviation': 'AST', 'gmtOffset': 10800, 'dst': '0', 'zoneStart': -719636812, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675363603, 'formatted': '2023-02-02 18:46:43'}
# Done
# Checking Asia/Almaty, Kazakhstan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'KZ', 'countryName': 'Kazakhstan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Almaty', 'abbreviation': 'ALMT', 'gmtOffset': 21600, 'dst': '0', 'zoneStart': 1099166400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675374405, 'formatted': '2023-02-02 21:46:45'}
# Done
# Checking Asia/Amman, Jordan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'JO', 'countryName': 'Jordan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Amman', 'abbreviation': 'EET', 'gmtOffset': 10800, 'dst': '0', 'zoneStart': 1666908000, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675363608, 'formatted': '2023-02-02 18:46:48'}
# Done
# Checking Asia/Anadyr, Russia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'RU', 'countryName': 'Russia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Anadyr', 'abbreviation': 'ANAT', 'gmtOffset': 43200, 'dst': '0', 'zoneStart': 1301151600, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675396010, 'formatted': '2023-02-03 03:46:50'}
# Done
# Checking Asia/Aqtau, Kazakhstan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'KZ', 'countryName': 'Kazakhstan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Aqtau', 'abbreviation': 'AQTT', 'gmtOffset': 18000, 'dst': '0', 'zoneStart': 1099173600, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675370812, 'formatted': '2023-02-02 20:46:52'}
# Done
# Checking Asia/Aqtobe, Kazakhstan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'KZ', 'countryName': 'Kazakhstan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Aqtobe', 'abbreviation': 'AQTT', 'gmtOffset': 18000, 'dst': '0', 'zoneStart': 1099170000, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675370814, 'formatted': '2023-02-02 20:46:54'}
# Done
# Checking Asia/Ashgabat, Turkmenistan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'TM', 'countryName': 'Turkmenistan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Ashgabat', 'abbreviation': 'TMT', 'gmtOffset': 18000, 'dst': '0', 'zoneStart': 695772000, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675370817, 'formatted': '2023-02-02 20:46:57'}
# Done
# Checking Asia/Atyrau, Kazakhstan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'KZ', 'countryName': 'Kazakhstan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Atyrau', 'abbreviation': 'AQTT', 'gmtOffset': 18000, 'dst': '0', 'zoneStart': 1099173600, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675370819, 'formatted': '2023-02-02 20:46:59'}
# Done
# Checking Asia/Baghdad, Iraq
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'IQ', 'countryName': 'Iraq', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Baghdad', 'abbreviation': 'AST', 'gmtOffset': 10800, 'dst': '0', 'zoneStart': 1191196800, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675363621, 'formatted': '2023-02-02 18:47:01'}
# Done
# Checking Asia/Bahrain, Bahrain
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'BH', 'countryName': 'Bahrain', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Bahrain', 'abbreviation': 'AST', 'gmtOffset': 10800, 'dst': '0', 'zoneStart': 76190400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675363623, 'formatted': '2023-02-02 18:47:03'}
# Done
# Checking Asia/Baku, Azerbaijan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AZ', 'countryName': 'Azerbaijan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Baku', 'abbreviation': 'AZT', 'gmtOffset': 14400, 'dst': '0', 'zoneStart': 1445731200, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675367226, 'formatted': '2023-02-02 19:47:06'}
# Done
# Checking Asia/Bangkok, Thailand
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'TH', 'countryName': 'Thailand', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Bangkok', 'abbreviation': 'ICT', 'gmtOffset': 25200, 'dst': '0', 'zoneStart': -1570084924, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675378028, 'formatted': '2023-02-02 22:47:08'}
# Done
# Checking Asia/Barnaul, Russia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'RU', 'countryName': 'Russia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Barnaul', 'abbreviation': 'MSK+4', 'gmtOffset': 25200, 'dst': '0', 'zoneStart': 1459022400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675378030, 'formatted': '2023-02-02 22:47:10'}
# Done
# Checking Asia/Beirut, Lebanon
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'LB', 'countryName': 'Lebanon', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Beirut', 'abbreviation': 'EET', 'gmtOffset': 7200, 'dst': '0', 'zoneStart': 1667077200, 'zoneEnd': 1679781599, 'nextAbbreviation': 'EEST', 'timestamp': 1675360033, 'formatted': '2023-02-02 17:47:13'}
# Done
# Checking Asia/Bishkek, Kyrgyzstan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'KG', 'countryName': 'Kyrgyzstan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Bishkek', 'abbreviation': 'KGT', 'gmtOffset': 21600, 'dst': '0', 'zoneStart': 1123783200, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675374435, 'formatted': '2023-02-02 21:47:15'}
# Done
# Checking Asia/Brunei, Brunei
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'BN', 'countryName': 'Brunei', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Brunei', 'abbreviation': 'BNT', 'gmtOffset': 28800, 'dst': '0', 'zoneStart': -767005200, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675381637, 'formatted': '2023-02-02 23:47:17'}
# Done
# Checking Asia/Chita, Russia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'RU', 'countryName': 'Russia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Chita', 'abbreviation': 'YAKT', 'gmtOffset': 32400, 'dst': '0', 'zoneStart': 1459015200, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675385239, 'formatted': '2023-02-03 00:47:19'}
# Done
# Checking Asia/Choibalsan, Mongolia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'MN', 'countryName': 'Mongolia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Choibalsan', 'abbreviation': 'CHOT', 'gmtOffset': 28800, 'dst': '0', 'zoneStart': 1474642800, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675381642, 'formatted': '2023-02-02 23:47:22'}
# Done
# Checking Asia/Colombo, Sri Lanka
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'LK', 'countryName': 'Sri Lanka', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Colombo', 'abbreviation': 'IST', 'gmtOffset': 19800, 'dst': '0', 'zoneStart': 1145039400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675372644, 'formatted': '2023-02-02 21:17:24'}
# Done
# Checking Asia/Damascus, Syria
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'SY', 'countryName': 'Syria', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Damascus', 'abbreviation': 'EET', 'gmtOffset': 10800, 'dst': '0', 'zoneStart': 1666904400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675363646, 'formatted': '2023-02-02 18:47:26'}
# Done
# Checking Asia/Dhaka, Bangladesh
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'BD', 'countryName': 'Bangladesh', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Dhaka', 'abbreviation': 'BST', 'gmtOffset': 21600, 'dst': '0', 'zoneStart': 1262278800, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675374448, 'formatted': '2023-02-02 21:47:28'}
# Done
# Checking Asia/Dili, Timor Leste
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'TL', 'countryName': 'Timor Leste', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Dili', 'abbreviation': 'TLT', 'gmtOffset': 32400, 'dst': '0', 'zoneStart': 969120000, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675385251, 'formatted': '2023-02-03 00:47:31'}
# Done
# Checking Asia/Dubai, United Arab Emirates
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AE', 'countryName': 'United Arab Emirates', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Dubai', 'abbreviation': 'GST', 'gmtOffset': 14400, 'dst': '0', 'zoneStart': -1577936472, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675367253, 'formatted': '2023-02-02 19:47:33'}
# Done
# Checking Asia/Dushanbe, Tajikistan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'TJ', 'countryName': 'Tajikistan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Dushanbe', 'abbreviation': 'TJT', 'gmtOffset': 18000, 'dst': '0', 'zoneStart': 684363600, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675370855, 'formatted': '2023-02-02 20:47:35'}
# Done
# Checking Asia/Famagusta, Cyprus
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'CY', 'countryName': 'Cyprus', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Famagusta', 'abbreviation': 'EET', 'gmtOffset': 7200, 'dst': '0', 'zoneStart': 1667091600, 'zoneEnd': 1679792399, 'nextAbbreviation': 'EEST', 'timestamp': 1675360058, 'formatted': '2023-02-02 17:47:38'}
# Done
# Checking Asia/Gaza, Palestinian Territory
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'PS', 'countryName': 'Palestinian Territory', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Gaza', 'abbreviation': 'EET', 'gmtOffset': 7200, 'dst': '0', 'zoneStart': 1666998000, 'zoneEnd': 1679702399, 'nextAbbreviation': 'EEST', 'timestamp': 1675360060, 'formatted': '2023-02-02 17:47:40'}
# Done
# Checking Asia/Hebron, Palestinian Territory
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'PS', 'countryName': 'Palestinian Territory', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Hebron', 'abbreviation': 'EET', 'gmtOffset': 7200, 'dst': '0', 'zoneStart': 1666998000, 'zoneEnd': 1679702399, 'nextAbbreviation': 'EEST', 'timestamp': 1675360062, 'formatted': '2023-02-02 17:47:42'}
# Done
# Checking Asia/Ho_Chi_Minh, Vietnam
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'VN', 'countryName': 'Vietnam', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Ho_Chi_Minh', 'abbreviation': 'IDT', 'gmtOffset': 25200, 'dst': '0', 'zoneStart': 171820800, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675378064, 'formatted': '2023-02-02 22:47:44'}
# Done
# Checking Asia/Hong_Kong, Hong Kong
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'HK', 'countryName': 'Hong Kong', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Hong_Kong', 'abbreviation': 'HKT', 'gmtOffset': 28800, 'dst': '0', 'zoneStart': 309292200, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675381667, 'formatted': '2023-02-02 23:47:47'}
# Done
# Checking Asia/Hovd, Mongolia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'MN', 'countryName': 'Mongolia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Hovd', 'abbreviation': 'HOVT', 'gmtOffset': 25200, 'dst': '0', 'zoneStart': 1474646400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675378069, 'formatted': '2023-02-02 22:47:49'}
# Done
# Checking Asia/Irkutsk, Russia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'RU', 'countryName': 'Russia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Irkutsk', 'abbreviation': 'IRKT', 'gmtOffset': 28800, 'dst': '0', 'zoneStart': 1414256400, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675381671, 'formatted': '2023-02-02 23:47:51'}
# Done
# Checking Asia/Jakarta, Indonesia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'ID', 'countryName': 'Indonesia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Jakarta', 'abbreviation': 'WIB', 'gmtOffset': 25200, 'dst': '0', 'zoneStart': -189415800, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675378073, 'formatted': '2023-02-02 22:47:53'}
# Done
# Checking Asia/Jayapura, Indonesia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'ID', 'countryName': 'Indonesia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Jayapura', 'abbreviation': 'WIT', 'gmtOffset': 32400, 'dst': '0', 'zoneStart': -189423000, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675385276, 'formatted': '2023-02-03 00:47:56'}
# Done
# Checking Asia/Jerusalem, Israel
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'IL', 'countryName': 'Israel', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Jerusalem', 'abbreviation': 'IST', 'gmtOffset': 7200, 'dst': '0', 'zoneStart': 1667084400, 'zoneEnd': 1679615999, 'nextAbbreviation': 'IDT', 'timestamp': 1675360078, 'formatted': '2023-02-02 17:47:58'}
# Done
# Checking Asia/Kabul, Afghanistan
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'AF', 'countryName': 'Afghanistan', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Kabul', 'abbreviation': 'AFT', 'gmtOffset': 16200, 'dst': '0', 'zoneStart': -788932800, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675369080, 'formatted': '2023-02-02 20:18:00'}
# Done
# Checking Asia/Kamchatka, Russia
# Doesn't exist, pulling data and adding to db...
# {'status': 'OK', 'message': '', 'countryCode': 'RU', 'countryName': 'Russia', 'regionName': '', 'cityName': '', 'zoneName': 'Asia/Kamchatka', 'abbreviation': 'PETT', 'gmtOffset': 43200, 'dst': '0', 'zoneStart': 1301151600, 'zoneEnd': None, 'nextAbbreviation': None, 'timestamp': 1675396083, 'formatted': '2023-02-03 03:48:03'}
# Done
# Checking Asia/Karachi, Pakistan
